# %% [markdown]
# Q1. Write a Python program to scrape all available books from the website(https://books.toscrape.com/) Books to Scrape – a live site built for practicing scraping (safe,legal, no anti-bot). <br>For each book, extract the following details:<br>1. Title<br>2. Price<br>3. Availability (In stock / Out of stock)<br>4. Star Rating (One, Two, Three, Four, Five)

# %%
import pandas as pd
import requests as req
from bs4 import BeautifulSoup as bs
url = "https://books.toscrape.com/catalogue/"

bookList = []
#print(soup.find_all("article", class_="product_pod"))

#recursive function to scrap page
def scrape_page(page_url):
    res = req.get(page_url)
    print(f"Scraping {res.url}")
    soup = bs(res.text, "html.parser")
    books = soup.find_all("article", class_="product_pod")

    for article in books:
        title = article.h3.a["title"]
        price = article.find("div", class_="product_price").find("p", class_="price_color").text.strip()
        availibility = article.find("div", class_="product_price").find("p", class_="instock availability").text.strip()=='In stock'
        rating = article.p["class"][1]

        
        d = dict()
        d["Title"] = title
        d["Price"]=price
        d["Availibility"]=availibility
        d["Rating"]=rating

        bookList.append(d)
        # print(title)
        # print(price)
        # print(availibility)
        # print(rating)

    #print(bookList)
    pager = soup.find("ul",class_="pager")
    next_page_link = next_page_link = pager.find("li", class_="next").find("a") if pager.find("li", class_="next") else None
    if(next_page_link is not None):
         next_page = next_page_link.get("href")
         next_page_url = url+next_page
         scrape_page(next_page_url)
    print("Scrapping completed successfully")

start_url = url+"page-1.html"

scrape_page(start_url)

pd.DataFrame(bookList).to_csv("books_data.csv",",")
# Out:
# Scraping https://books.toscrape.com/catalogue/page-1.html
# Scraping https://books.toscrape.com/catalogue/page-2.html
# Scraping https://books.toscrape.com/catalogue/page-3.html
# Scraping https://books.toscrape.com/catalogue/page-4.html
# Scraping https://books.toscrape.com/catalogue/page-5.html
# Scraping https://books.toscrape.com/catalogue/page-6.html
# Scraping https://books.toscrape.com/catalogue/page-7.html
# Scraping https://books.toscrape.com/catalogue/page-8.html
# Scraping https://books.toscrape.com/catalogue/page-9.html
# Scraping https://books.toscrape.com/catalogue/page-10.html
# Scraping https://books.toscrape.com/catalogue/page-11.html
# Scraping https://books.toscrape.com/catalogue/page-12.html
# Scraping https://books.toscrape.com/catalogue/page-13.html
# Scraping https://books.toscrape.com/catalogue/page-14.html
# Scraping https://books.toscrape.com/catalogue/page-15.html
# Scraping https://books.toscrape.com/catalogue/page-16.html
# Scraping https://books.toscrape.com/catalogue/page-17.html
# Scraping https://books.toscrape.com/catalogue/page-18.html
# Scraping https://books.toscrape.com/catalogue/page-19.html
# Scraping https://books.toscrape.com/catalogue/page-20.html
# Scraping https://books.toscrape.com/catalogue/page-21.html
# Scraping https://books.toscrape.com/catalogue/page-22.html
# Scraping https://books.toscrape.com/catalogue/page-23.html
# Scraping https://books.toscrape.com/catalogue/page-24.html
# Scraping https://books.toscrape.com/catalogue/page-25.html
# Scraping https://books.toscrape.com/catalogue/page-26.html
# Scraping https://books.toscrape.com/catalogue/page-27.html
# Scraping https://books.toscrape.com/catalogue/page-28.html
# Scraping https://books.toscrape.com/catalogue/page-29.html
# Scraping https://books.toscrape.com/catalogue/page-30.html
# Scraping https://books.toscrape.com/catalogue/page-31.html
# Scraping https://books.toscrape.com/catalogue/page-32.html
# Scraping https://books.toscrape.com/catalogue/page-33.html
# Scraping https://books.toscrape.com/catalogue/page-34.html
# Scraping https://books.toscrape.com/catalogue/page-35.html
# Scraping https://books.toscrape.com/catalogue/page-36.html
# Scraping https://books.toscrape.com/catalogue/page-37.html
# Scraping https://books.toscrape.com/catalogue/page-38.html
# Scraping https://books.toscrape.com/catalogue/page-39.html
# Scraping https://books.toscrape.com/catalogue/page-40.html
# Scraping https://books.toscrape.com/catalogue/page-41.html
# Scraping https://books.toscrape.com/catalogue/page-42.html
# Scraping https://books.toscrape.com/catalogue/page-43.html
# Scraping https://books.toscrape.com/catalogue/page-44.html
# Scraping https://books.toscrape.com/catalogue/page-45.html
# Scraping https://books.toscrape.com/catalogue/page-46.html
# Scraping https://books.toscrape.com/catalogue/page-47.html
# Scraping https://books.toscrape.com/catalogue/page-48.html
# Scraping https://books.toscrape.com/catalogue/page-49.html
# Scraping https://books.toscrape.com/catalogue/page-50.html
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# Scrapping completed successfully
# C:\Users\dheer\AppData\Local\Temp\ipykernel_9576\3396827857.py:48: FutureWarning: Starting with pandas version 3.0 all arguments of to_csv except for the argument 'path_or_buf' will be keyword-only.
#   pd.DataFrame(bookList).to_csv("books_data.csv",",")

# %% [markdown]
# Q2. Write a Python program to scrape the IMDB Top 250 Movies list(https://www.imdb.com/chart/top/) .<br> For each movie, extract the following details:<br>1. Rank (1–250)<br>2. Movie Title<br>3. Year of Release<br>4. IMDB Rating<br>Store the results in a Pandas DataFrame and export it to a CSV file named imdb_top250.csv.<br>(Note: Use Selenium/Playwright to scrape the required details from this website)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

driver = webdriver.Chrome()
driver.get("https://www.imdb.com/chart/top/")

# Find all movie elements
movie_container = driver.find_elements(By.CSS_SELECTOR, "div.sc-15ac7568-0.jQHOho.cli-children")

movie_list = []

# Iterate through the list and print each movie title
for container in movie_container:
    rank,name = container.find_element(By.CSS_SELECTOR, "h3").text.split(".",1) #split into two parts by first .(dot char)
    release_year = container.find_element(By.CSS_SELECTOR,"span.sc-15ac7568-7.cCsint.cli-title-metadata-item").text
    rating = container.find_element(By.CSS_SELECTOR, "span.ipc-rating-star--rating").text
    
    d = dict()
    d = {
        "Rank": rank.strip(),
        "Title":name.strip(),
        "Year of Releas": release_year,
        "IMDB Rating": rating
    }
    movie_list.append(d)
    #print(d)
driver.quit()
pd.DataFrame(movie_list).to_csv(path_or_buf="imdb_top250.csv", index=False)
print("Movie List saved successfully, imdb_top250.csv")
# Out:
# Movie List saved successfully, imdb_top250.csv

# %% [markdown]
# Q3. Write a Python program to scrape the weather information for top world cities from the given website (https://www.timeanddate.com/weather/) . For each city, extract the followingdetails:<br><br>1. City Name<br>2. Temperature<br>3. Weather Condition (e.g., Clear, Cloudy, Rainy, etc.)<br><br>Store the results in a Pandas DataFrame and export it to a CSV file named weather.csv.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

driver = webdriver.Chrome()
driver.get("https://www.timeanddate.com/weather/")

rows = driver.find_elements(By.CSS_SELECTOR, "table tbody tr")

city_temp_list = []


#extract city, temp, and condition
def extract_city_data(tds, col_start):
    try:
        city_name = tds[col_start].text.strip()
        if not city_name:  # skip if city not available
            return None

        condition = tds[col_start+2].find_element(By.CSS_SELECTOR, "img").get_attribute("title") \
                    if tds[col_start+2].find_elements(By.CSS_SELECTOR, "img") else "N/A"

        temperature = tds[col_start+3].text.strip() if tds[col_start+3].text.strip() else "N/A"

        return {
            "City": city_name,
            "Temperature": temperature,
            "Weather Condition": condition
        }
    except Exception:
        return None

for j in range(0,12,4):
    for row in rows:
        tds = row.find_elements(By.CSS_SELECTOR, "td")
        if len(tds) >= 4:
            d = extract_city_data(tds, j)
            if d:
                print(f"Saving {d}")
                city_temp_list.append(d)
driver.quit()

# Saving CSV files
pd.DataFrame(city_temp_list).to_csv("weather.csv", index=False)
print(f"{len(city_temp_list)} cities' temperatures saved successfully, as weather.csv")
# Out:
# Saving {'City': 'Accra', 'Temperature': '24 °C', 'Weather Condition': 'Scattered clouds. Mild.'}
# Saving {'City': 'Addis Ababa', 'Temperature': '17 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Adelaide', 'Temperature': '7 °C', 'Weather Condition': 'Chilly.'}
# Saving {'City': 'Algiers', 'Temperature': '28 °C', 'Weather Condition': 'Overcast. Warm.'}
# Saving {'City': 'Almaty', 'Temperature': '15 °C', 'Weather Condition': 'Passing clouds. Refreshingly cool.'}
# Saving {'City': 'Amman', 'Temperature': '25 °C', 'Weather Condition': 'Clear. Warm.'}
# Saving {'City': 'Amsterdam *', 'Temperature': '21 °C', 'Weather Condition': 'Sunny. Mild.'}
# Saving {'City': 'Anadyr', 'Temperature': '5 °C', 'Weather Condition': 'Overcast. Quite cool.'}
# Saving {'City': 'Anchorage *', 'Temperature': '13 °C', 'Weather Condition': 'Partly sunny. Cool.'}
# Saving {'City': 'Ankara', 'Temperature': '24 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Antananarivo', 'Temperature': '14 °C', 'Weather Condition': 'Passing clouds. Cool.'}
# Saving {'City': 'Asuncion', 'Temperature': '21 °C', 'Weather Condition': 'Thunderstorms. More clouds than sun. Mild.'}
# Saving {'City': 'Athens *', 'Temperature': '32 °C', 'Weather Condition': 'Passing clouds. Hot.'}
# Saving {'City': 'Atlanta *', 'Temperature': '25 °C', 'Weather Condition': 'Scattered clouds. Warm.'}
# Saving {'City': 'Auckland', 'Temperature': '13 °C', 'Weather Condition': 'Light rain. Partly cloudy. Cool.'}
# Saving {'City': 'Bangkok', 'Temperature': '27 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Barcelona *', 'Temperature': '27 °C', 'Weather Condition': 'Passing clouds. Pleasantly warm.'}
# Saving {'City': 'Beijing', 'Temperature': '21 °C', 'Weather Condition': 'Clear. Mild.'}
# Saving {'City': 'Belgrade *', 'Temperature': '25 °C', 'Weather Condition': 'Clear. Warm.'}
# Saving {'City': 'Bengaluru', 'Temperature': '21 °C', 'Weather Condition': 'Partly cloudy. Mild.'}
# Saving {'City': 'Berlin *', 'Temperature': '24 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Bogota', 'Temperature': '17 °C', 'Weather Condition': 'Drizzle. Mostly cloudy. Mild.'}
# Saving {'City': 'Boston *', 'Temperature': '21 °C', 'Weather Condition': 'Partly sunny. Mild.'}
# Saving {'City': 'Brasilia', 'Temperature': '28 °C', 'Weather Condition': 'Scattered clouds. Pleasantly warm.'}
# Saving {'City': 'Brisbane', 'Temperature': '13 °C', 'Weather Condition': 'Cool.'}
# Saving {'City': 'Brussels *', 'Temperature': '20 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Bucharest *', 'Temperature': '26 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Budapest *', 'Temperature': '22 °C', 'Weather Condition': 'Clear. Mild.'}
# Saving {'City': 'Buenos Aires', 'Temperature': '11 °C', 'Weather Condition': 'Overcast. Cool.'}
# Saving {'City': 'Cairo *', 'Temperature': '31 °C', 'Weather Condition': 'Clear. Warm.'}
# Saving {'City': 'Calgary *', 'Temperature': '23 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Canberra', 'Temperature': '4 °C', 'Weather Condition': 'Partly cloudy. Chilly.'}
# Saving {'City': 'Cape Town', 'Temperature': '16 °C', 'Weather Condition': 'Passing clouds. Cool.'}
# Saving {'City': 'Caracas', 'Temperature': '32 °C', 'Weather Condition': 'Scattered clouds. Hot.'}
# Saving {'City': 'Casablanca *', 'Temperature': '22 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Chicago *', 'Temperature': '24 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Copenhagen *', 'Temperature': '20 °C', 'Weather Condition': 'Overcast. Mild.'}
# Saving {'City': 'Dallas *', 'Temperature': '31 °C', 'Weather Condition': 'Scattered clouds. Warm.'}
# Saving {'City': 'Dar es Salaam', 'Temperature': '27 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Darwin', 'Temperature': '22 °C', 'Weather Condition': 'Clear. Mild.'}
# Saving {'City': 'Denver *', 'Temperature': '25 °C', 'Weather Condition': 'Passing clouds. Pleasantly warm.'}
# Saving {'City': 'Detroit *', 'Temperature': '24 °C', 'Weather Condition': 'Sunny. Mild.'}
# Saving {'City': 'Dhaka', 'Temperature': '29 °C', 'Weather Condition': 'Thunderstorms. Low clouds. Warm.'}
# Saving {'City': 'Doha', 'Temperature': '36 °C', 'Weather Condition': 'Clear. Extremely hot.'}
# Saving {'City': 'Dubai', 'Temperature': '35 °C', 'Weather Condition': 'Haze. Extremely hot.'}
# Saving {'City': 'Dublin *', 'Temperature': '15 °C', 'Weather Condition': 'Broken clouds. Cool.'}
# Saving {'City': 'Edmonton *', 'Temperature': '25 °C', 'Weather Condition': 'Partly sunny. Warm.'}
# Saving {'City': 'Frankfurt *', 'Temperature': '19 °C', 'Weather Condition': 'Clear. Mild.'}
# Saving {'City': 'Guatemala City', 'Temperature': '25 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Halifax *', 'Temperature': '24 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Hanoi', 'Temperature': '26 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Harare', 'Temperature': '20 °C', 'Weather Condition': 'Clear. Mild.'}
# Saving {'City': 'Havana *', 'Temperature': '33 °C', 'Weather Condition': 'Partly sunny. Hot.'}
# Saving {'City': 'Helsinki *', 'Temperature': '11 °C', 'Weather Condition': 'Fog. Cool.'}
# Saving {'City': 'Hong Kong', 'Temperature': '29 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Honolulu', 'Temperature': '27 °C', 'Weather Condition': 'Broken clouds. Warm.'}
# Saving {'City': 'Houston *', 'Temperature': '26 °C', 'Weather Condition': 'Strong thunderstorms. Fog. Warm.'}
# Saving {'City': 'Indianapolis *', 'Temperature': '26 °C', 'Weather Condition': 'Passing clouds. Pleasantly warm.'}
# Saving {'City': 'Islamabad', 'Temperature': '24 °C', 'Weather Condition': 'Thundershowers. Overcast. Mild.'}
# Saving {'City': 'Istanbul', 'Temperature': '25 °C', 'Weather Condition': 'Clear. Warm.'}
# Saving {'City': 'Jakarta', 'Temperature': '27 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Jerusalem *', 'Temperature': '22 °C', 'Weather Condition': 'Mild.'}
# Saving {'City': 'Johannesburg', 'Temperature': '28 °C', 'Weather Condition': 'Sunny. Pleasantly warm.'}
# Saving {'City': 'Karachi', 'Temperature': '28 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Kathmandu', 'Temperature': '23 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Kingston', 'Temperature': '34 °C', 'Weather Condition': 'Hot.'}
# Saving {'City': 'Kinshasa', 'Temperature': '27 °C', 'Weather Condition': 'Clear. Warm.'}
# Saving {'City': 'Kiritimati', 'Temperature': '28 °C', 'Weather Condition': 'Partly sunny. Warm.'}
# Saving {'City': 'Kolkata', 'Temperature': '25 °C', 'Weather Condition': 'Thunderstorms. Partly cloudy. Warm.'}
# Saving {'City': 'Kuala Lumpur', 'Temperature': '24 °C', 'Weather Condition': 'Thunderstorms. Passing clouds. Mild.'}
# Saving {'City': 'Kyiv *', 'Temperature': '26 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'La Paz', 'Temperature': '15 °C', 'Weather Condition': 'Scattered clouds. Refreshingly cool.'}
# Saving {'City': 'Lahore', 'Temperature': '24 °C', 'Weather Condition': 'Light rain. Partly cloudy. Mild.'}
# Saving {'City': 'Las Vegas *', 'Temperature': '36 °C', 'Weather Condition': 'Passing clouds. Extremely hot.'}
# Saving {'City': 'Lisbon *', 'Temperature': '21 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'London *', 'Temperature': '15 °C', 'Weather Condition': 'Scattered showers. Partly sunny. Cool.'}
# Saving {'City': 'Los Angeles *', 'Temperature': '27 °C', 'Weather Condition': 'Sunny. Warm.'}
# Saving {'City': 'Madrid *', 'Temperature': '22 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Managua', 'Temperature': '33 °C', 'Weather Condition': 'Scattered clouds. Hot.'}
# Saving {'City': 'Manila', 'Temperature': '26 °C', 'Weather Condition': 'Overcast. Warm.'}
# Saving {'City': 'Melbourne', 'Temperature': '9 °C', 'Weather Condition': 'Overcast. Cool.'}
# Saving {'City': 'Mexico City', 'Temperature': '23 °C', 'Weather Condition': 'Partly sunny. Mild.'}
# Saving {'City': 'Miami *', 'Temperature': '32 °C', 'Weather Condition': 'Partly sunny. Hot.'}
# Saving {'City': 'Minneapolis *', 'Temperature': '21 °C', 'Weather Condition': 'Partly sunny. Mild.'}
# Saving {'City': 'Minsk', 'Temperature': '17 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Montevideo', 'Temperature': '14 °C', 'Weather Condition': 'Drizzle. Overcast. Cool.'}
# Saving {'City': 'Montréal *', 'Temperature': '26 °C', 'Weather Condition': 'Scattered clouds. Warm.'}
# Saving {'City': 'Moscow', 'Temperature': '17 °C', 'Weather Condition': 'Clear. Cool.'}
# Saving {'City': 'Mumbai', 'Temperature': '27 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Nairobi', 'Temperature': '21 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Nassau *', 'Temperature': '30 °C', 'Weather Condition': 'Thunderstorms. Broken clouds. Warm.'}
# Saving {'City': 'New Delhi', 'Temperature': '25 °C', 'Weather Condition': 'Fog. Warm.'}
# Saving {'City': 'New Orleans *', 'Temperature': '29 °C', 'Weather Condition': 'Broken clouds. Warm.'}
# Saving {'City': 'New York *', 'Temperature': '25 °C', 'Weather Condition': 'Sunny. Pleasantly warm.'}
# Saving {'City': 'Oslo *', 'Temperature': '18 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Ottawa *', 'Temperature': '25 °C', 'Weather Condition': 'Scattered clouds. Warm.'}
# Saving {'City': 'Paris *', 'Temperature': '17 °C', 'Weather Condition': 'Partly sunny. Mild.'}
# Saving {'City': 'Perth', 'Temperature': '8 °C', 'Weather Condition': 'Passing clouds. Cool.'}
# Saving {'City': 'Philadelphia *', 'Temperature': '27 °C', 'Weather Condition': 'Broken clouds. Pleasantly warm.'}
# Saving {'City': 'Phoenix', 'Temperature': '37 °C', 'Weather Condition': 'Broken clouds. Extremely hot.'}
# Saving {'City': 'Prague *', 'Temperature': '22 °C', 'Weather Condition': 'Clear. Mild.'}
# Saving {'City': 'Reykjavik', 'Temperature': '15 °C', 'Weather Condition': 'Broken clouds. Cool.'}
# Saving {'City': 'Rio de Janeiro', 'Temperature': '24 °C', 'Weather Condition': 'Broken clouds. Mild.'}
# Saving {'City': 'Riyadh', 'Temperature': '35 °C', 'Weather Condition': 'Clear. Extremely hot.'}
# Saving {'City': 'Rome *', 'Temperature': '26 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Salt Lake City *', 'Temperature': '30 °C', 'Weather Condition': 'Passing clouds. Pleasantly warm.'}
# Saving {'City': 'San Francisco *', 'Temperature': '20 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'San Juan', 'Temperature': '32 °C', 'Weather Condition': 'Scattered clouds. Hot.'}
# Saving {'City': 'San Salvador', 'Temperature': '30 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Santiago', 'Temperature': '18 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Santo Domingo', 'Temperature': '32 °C', 'Weather Condition': 'Scattered clouds. Hot.'}
# Saving {'City': 'São Paulo', 'Temperature': '21 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Seattle *', 'Temperature': '18 °C', 'Weather Condition': 'Overcast. Mild.'}
# Saving {'City': 'Seoul', 'Temperature': '22 °C', 'Weather Condition': 'Clear. Mild.'}
# Saving {'City': 'Shanghai', 'Temperature': '29 °C', 'Weather Condition': 'Clear. Warm.'}
# Saving {'City': 'Singapore', 'Temperature': '26 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Sofia *', 'Temperature': '22 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': "St. John's *", 'Temperature': '13 °C', 'Weather Condition': 'Partly sunny. Cool.'}
# Saving {'City': 'Stockholm *', 'Temperature': '17 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Suva', 'Temperature': '22 °C', 'Weather Condition': 'Overcast. Mild.'}
# Saving {'City': 'Sydney', 'Temperature': '12 °C', 'Weather Condition': 'Mostly cloudy. Cool.'}
# Saving {'City': 'Taipei', 'Temperature': '27 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Tallinn *', 'Temperature': '15 °C', 'Weather Condition': 'Overcast. Cool.'}
# Saving {'City': 'Tashkent', 'Temperature': '21 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Tegucigalpa', 'Temperature': '29 °C', 'Weather Condition': 'Passing clouds. Pleasantly warm.'}
# Saving {'City': 'Tehran', 'Temperature': '29 °C', 'Weather Condition': 'Clear. Pleasantly warm.'}
# Saving {'City': 'Tokyo', 'Temperature': '29 °C', 'Weather Condition': 'Warm.'}
# Saving {'City': 'Toronto *', 'Temperature': '23 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Vancouver *', 'Temperature': '18 °C', 'Weather Condition': 'Overcast. Mild.'}
# Saving {'City': 'Vienna *', 'Temperature': '22 °C', 'Weather Condition': 'Clear. Mild.'}
# Saving {'City': 'Warsaw *', 'Temperature': '20 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Washington DC *', 'Temperature': '26 °C', 'Weather Condition': 'Partly sunny. Pleasantly warm.'}
# Saving {'City': 'Winnipeg *', 'Temperature': '26 °C', 'Weather Condition': 'Warm.'}
# Saving {'City': 'Yangon', 'Temperature': '25 °C', 'Weather Condition': 'Passing clouds. Warm.'}
# Saving {'City': 'Zagreb *', 'Temperature': '23 °C', 'Weather Condition': 'Passing clouds. Mild.'}
# Saving {'City': 'Zürich *', 'Temperature': '17 °C', 'Weather Condition': 'Thunderstorms. Partly cloudy. Mild.'}
# failed
# failed
# 136 cities' temperatures saved successfully, as weather.csv

# %%
for i in range(0,12,4):
    print(i)
# Out:
# 0
# 4
# 8
