# %% [markdown]
# ## PART-I: Based on Feature Selection

# %%
import pandas as pd
data = pd.read_csv('AWCustomers.csv')

df = pd.DataFrame(data)
df.head(5)
# Out:
#    CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0       21173   NaN      Chad          C      Yuan    NaN
# 1       13249   NaN      Ryan        NaN     Perry    NaN
# 2       29350   NaN     Julia        NaN  Thompson    NaN
# 3       13503   NaN  Theodore        NaN     Gomez    NaN
# 4       22803   NaN  Marshall          J      Shan    NaN
#
#              AddressLine1 AddressLine2         City    StateProvinceName  ...  \
# 0      7090 C. Mount Hood          NaN   Wollongong      New South Wales  ...
# 1     3651 Willow Lake Rd          NaN      Shawnee     British Columbia  ...
# 2  1774 Tice Valley Blvd.          NaN  West Covina           California  ...
# 3         2103 Baldwin Dr          NaN    Liverpool              England  ...
# 4         Am Gallberg 234          NaN        Werne  Nordrhein-Westfalen  ...
#
#          Education      Occupation Gender MaritalStatus HomeOwnerFlag  \
# 0        Bachelors        Clerical      M             M             1
# ...

# %% [markdown]
# (b) Create a new Data Frame with the selected attributes only.

# %%
df_filtered= df.filter(['CustomerID','FirstName','CountryRegionName','PostalCode','PhoneNumber','Occupation','HomeOwnerFlag','NumberCarOwned','Gender','MaritalStatus','NumberChildrenAtHome','YearlyIncome']).copy()
df_filtered
# Out:
#        CustomerID FirstName CountryRegionName PostalCode          PhoneNumber  \
# 0           21173      Chad         Australia       2500  1 (11) 500 555-0115
# 1           13249      Ryan            Canada    V9B 2C3         787-555-0136
# 2           29350     Julia     United States      91791         120-555-0111
# 3           13503  Theodore    United Kingdom     L4 4HB  1 (11) 500 555-0167
# 4           22803  Marshall           Germany      59368  1 (11) 500 555-0113
# ...           ...       ...               ...        ...                  ...
# 18356       25414     Grace     United States      92118         292-555-0130
# 18357       11459     Tasha         Australia       2444  1 (11) 500 555-0171
# 18358       12160    Jaclyn     United States      97005         819-555-0110
# 18359       14353      Erin            Canada    V7L 4J4         791-555-0118
# 18360       16676    Amanda     United States      91941         553-555-0122
#
# ...

# %% [markdown]
# (c) Determine a Data value type

# %% [markdown]
# <b>1. Discrete</b><br>
#     i. Nominal<br>
#         CustomerID, PostalCode, PhoneNumber
#         <br>
#     ii. Ordinal<br>
# <b>2. Continous</b><br>
#     i. Interval<br>
#         HomeOwnerFlag, NumberChildrenAtHome, YearlyIncome
#     ii. Ratio<br>
# <b>3. Text</b><br>
#     i. Nominal<br>
#         FirstName
#         <br>
#     ii. Categorical<br>
#         CountryRegionName,PostalCode ,Occupation, Gender, MaritalStatus,

# %% [markdown]
# ## PART-II: Preprocessing and Transformation

# %%
df_filtered.info()
df_clean = df_filtered.dropna().copy()
print("Shape after deleting removing null values", df_clean.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18361 entries, 0 to 18360
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            18361 non-null  int64
#  1   FirstName             18361 non-null  object
#  2   CountryRegionName     18361 non-null  object
#  3   PostalCode            18361 non-null  object
#  4   PhoneNumber           18361 non-null  object
#  5   Occupation            18361 non-null  object
#  6   HomeOwnerFlag         18361 non-null  int64
#  7   Gender                18361 non-null  object
#  8   MaritalStatus         18361 non-null  object
#  9   NumberChildrenAtHome  18361 non-null  int64
#  10  YearlyIncome          18361 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 1.5+ MB
# Shape after deleting removing null values (18361, 11)

# %%
numericalCols = ['CustomerID','HomeOwnerFlag','NumberChildrenAtHome','YearlyIncome']
categoricalCols = ['FirstName','CountryRegionName','PostalCode','PhoneNumber','Occupation','Gender','MaritalStatus']

# %%
#min-max method normalization
scaler = MinMaxScaler()
